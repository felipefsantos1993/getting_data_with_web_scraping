# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\felip\appdata\local\programs\python\python312\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\felip\appdata\local\programs\python\python312\lib\site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\felip\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\felip\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->bs4) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import os
#import re
#import io
#import shutil
#import zipfile
import requests
import warnings
#import numpy as np
from bs4 import BeautifulSoup
#from datetime import datetime as dt

warnings.filterwarnings("ignore")

# %%
url = f'https://dados.anvisa.gov.br/dados/'
folder_path = f'/Volumes/development/lab/upload_files/data_management/ANVISA/'

page = requests.get(url, verify=False)
anvisa_main_page_text = BeautifulSoup(page.content,'html.parser')

print(anvisa_main_page_text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en"><head><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><title>index - powered by h5ai v0.29.0 (https://larsjung.de/h5ai/)</title><meta content="index - powered by h5ai v0.29.0 (https://larsjung.de/h5ai/)" name="description"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="/_h5ai/public/images/favicon/favicon-16-32.ico" rel="shortcut icon"/><link href="/_h5ai/public/images/favicon/favicon-152.png" rel="apple-touch-icon-precomposed" type="image/png"/><link href="/_h5ai/public/css/styles.css" rel="stylesheet"/><script data-module="index" src="/_h5ai/public/js/scripts.js"></script><link class="x-head" href="//fonts.googleapis.com/css?family=Ubuntu:300,400,700%7CUbuntu+Mono:400,700" rel="stylesheet"/><style class="x-head">#root,input,select{font-family:"Ubuntu","Roboto","Helvetica","Arial","sans-serif"!important}pre,code{font-family:"Ubuntu Mono","Monaco","Lucida Sans Typewriter","monospace"!important}</style></head><body class="index" id="root"><div id="fallback-hints"><span class="noJsMsg">Works best with JavaScript enabled!</span><span class="noBrowserMsg">Works best in <a href="http://browsehappy.com">modern browsers</a>!</span><span class="backlink"><a href="https://larsjung.de/h5ai/" title="h5ai v0.29.0 - Modern HTTP web server index.">powered by h5ai</a></span></div><div id="fallback"><table><tr><th class="fb-i"></th><th class="fb-n"><span>Name</span></th><th class="fb-d"><span>Last modified</span></th><th class="fb-s"><span>Size</span></th></tr><tr><td class="fb-i"><img alt="folder-parent" src="/_h5ai/public/images/fallback/folder-parent.png"/></td><td class="fb-n"><a href="..">Parent Directory</a></td><td class="fb-d"></td><td class="fb-s"></td></tr><tr><td class="fb-i"><img alt="folder" src="/_h5ai/public/images/fallback/folder.png"/></td><td class="fb-n"><a href="/dados/CONSULTAS/">CONSULTAS</a></td><td class="fb-d">2025-04-25 18:23</td><td class="fb-s"></td></tr><tr><td class="fb-i"><img alt="folder" src="/_h5ai/public/images/fallback/folder.png"/></td><td class="fb-n"><a href="/dados/SNGPC/">SNGPC</a></td><td class="fb-d">2023-01-05 13:13</td><td class="fb-s"></td></tr><tr><td class="fb-i"><img alt="file" src="/_h5ai/public/images/fallback/file.png"/></td><td class="fb-n"><a href="/dados/CICLO_ANALISE_PETICOES_AGROTOXICO.CSV">CICLO_ANALISE_PETICOES_AGROTOXICO.CSV</a></td><td class="fb-d">2023-11-07 15:14</td><td class="fb-s">23116 KB</td></tr><tr><td class="fb-i"><img alt="file" src="/_h5ai/public/images/fallback/file.png"/></td><td class="fb-n"><a href="/dados/CICLO_ANALISE_PETICOES_ALIMENTO.CSV">CICLO_ANALISE_PETICOES_ALIMENTO.CSV</a></td><td class="fb-d">2025-04-24 12:35</td><td class="fb-s">17053 KB</td></tr><tr><td class="fb-i"><img alt="file" src="/_h5ai/public/images/fallback/file.png"/></td><td class="fb-n"><a href="/dados/CICLO_ANALISE_PETICOES_ANDAMENTO_ALIMENTO.CSV">CICLO_ANALISE_PETICOES_ANDAMENTO_ALIMENTO.CSV</a></td><td class="fb-d">2025-04-24 12:36</td><td class="fb-s">346 KB</td></tr><tr><td class="fb-i"><img alt="file" src="/_h5ai/public/images/fallback/file.png"/></td><td class="fb-n"><a href="/dados/CICLO_ANALISE_PETICOES_ANDAMENTO_COSMETICO.CSV">CICLO_ANALISE_PETICOES_ANDAMENTO_COSMETICO.CSV</a></td><td class="fb-d">2025-04-24 12:36</td><td class="fb-s">2410 KB</td></tr><tr><td class="fb-i"><img alt="file" src="/_h5ai/public/images/fallback/file.png"/></td><td class="fb-n"><a href="/dados/CICLO_ANALISE_PETICOES_ANDAMENTO_EMPRESA.CSV">CICLO_ANALISE_PETICOES_ANDAMENTO_EMPRESA.CSV</a></td><td class="fb-d">2025-04-24 12:39</td><td class="fb-s">13776 KB</td></tr><tr><td class="fb-i"><img alt="file" src="/_h5ai/public/images/fallback/file.png"/></td><td class="fb-n"><a href="/dados/CICLO_ANALISE_PETICOES_ANDAMENTO_INSUMO_FARMACEUTICO.CSV">CICLO_ANALISE_PETICOES_ANDAMENTO_INSUMO_FARMACEUTICO.CSV</a></td><td class="fb-d">2025-04-24 12:37</td><td class="fb-s">1873 KB</td></tr><tr><td class="fb-i"><img alt="file" src="/ ...

# %%
import pandas as pd
import requests
from io import StringIO

url = 'https://dados.anvisa.gov.br/dados/TA_PRODUTO_SAUDE_SITE.csv'
response = requests.get(url, verify=False)
df = pd.read_csv(StringIO(response.text), sep=';', low_memory=False, encoding='utf-8')

display(df)
# Out:
#         NUMERO_REGISTRO_CADASTRO    NUMERO_PROCESSO  \
# 0                    10330710009    250000000370079
# 1                    10246810016    250000000659575
# 2                    10163770014    250000000750068
# 3                    10163770014    250000000750068
# 4                    10196320017    250000001639918
# ...                          ...                ...
# 108001               80130430050  25351999292201684
# 108002               80130430050  25351999292201684
# 108003               81327670011  25351999982201624
# 108004               81639889003  25351999998202096
# 108005               10041120135      2599101183677
#
#                           NOME_TECNICO CLASSE_RISCO  \
# 0                              Agulhas           II
# 1                       PROTEÍNA TOTAL           II
# 2             Preservativos Masculinos          III
# 3             Preservativos Masculinos          III
# 4                            Cateteres           IV
# ...                                ...          ...
# 108001               Lentes de Contato           II
# 108002               Lentes de Contato           II
# 108003  PROCALCITONINA PCT - CLASSE II           II
# 108004             Lubrificante Intimo           II
# 108005  Agente de Obturacao Provisoria           II
#
#                                            NOME_COMERCIAL  \
# 0          AGULHA PARA PUNĮÃO COM ACESSO PERCUTÂNEA RENAL
# 1                             PROTAL METODO COLORIMETRICO
# 2                                           PRESERV EXTRA
# 3                                           PRESERV EXTRA
# 4                                     CATETER DUPLO LUMEN
# ...                                                   ...
# 108001                      Lentes de Contato Comfilcon A
# 108002                      Lentes de Contato Comfilcon A
# 108003                        Cartucho de teste mLabs PCT
# 108004                                     Sete Sensaįões
# 108005  CAVITINE - FORRADOR DE CAVIDADES E VERNIZ PARA...
#
#         CNPJ_DETENTOR_REGISTRO_CADASTRO  \
# 0                        54756242000139
# 1                        72807043000194
# 2                        58430828000160
# 3                        58430828000160
# 4                        51943645000107
# ...                                 ...
# 108001                    4998723000182
# 108002                    4998723000182
# 108003                   22940751000120
# 108004                    5304403000148
# 108005                   68567650000157
#
#                                DETENTOR_REGISTRO_CADASTRO  \
# 0            HANDLE COMERCIO DE EQUIPAMENTOS MEDICOS LTDA
# 1            LABORLAB PRODUTOS PARA LABORATÓRIOS LTDA EPP
# 2                                  BLAU FARMACEUTICA S.A.
# 3                                  BLAU FARMACEUTICA S.A.
# 4       BIOMEDICAL EQUIPAMENTOS E PRODUTOS MÉDICO-CIRÚ...
# ...                                                   ...
# 108001                       COOPERVISION DO BRASIL LTDA.
# 108002                       COOPERVISION DO BRASIL LTDA.
# 108003  DNEDX COMERCIO E SERVICOS PARA PRODUTOS DA SAU...
# 108004             NS PRODUTOS E SISTEMAS DE HIGIENE LTDA
# 108005                    S S WHITE ARTIGOS DENTARIOS S/A
#
#                                           NOME_FABRICANTE  \
# 0                                       COOK INCORPORATED
# 1            LABORLAB PRODUTOS PARA LABORATÓRIOS LTDA EPP
# 2                                                     NaN
# 3                                         SURETEX LIMITED
# 4       BIOMEDICAL EQUIPAMENTOS E PRODUTOS MÉDICO-CIRÚ...
# ...                                                   ...
# 108001                                  COOPERVISION INC.
# 108002                     COOPERVISION MANUFACTURING LTD
# 108003               MICROPOINT BIOTECHNOLOGIES CO., LTD.
# 108004             NS PRODUTOS E SISTEMAS DE HIGIENE LTDA
# 108005                                                NaN
#
#                  NOME_PAIS_FABRIC DT_PUB_REGISTRO_CADASTRO  \
# 0       ESTADOS UNIDOS DA AMÉRICA               09/05/2000
# 1                          BRASIL               29/02/1996
# 2                             NaN               26/05/2000
# 3             TAILÂNDIA, REINO DA               26/05/2000
# 4                          BRASIL               11/03/1999
# ...                           ...                      ...
# 108001  ESTADOS UNIDOS DA AMÉRICA               08/08/2016
# 108002                REINO UNIDO               08/08/2016
# 108003   CHINA, REPÚBLICA POPULAR               05/09/2016
# 108004                     BRASIL               01/10/2020
# 108005                        NaN               28/05/1999
#
#        VALIDADE_REGISTRO_CADASTRO  DT_ATUALIZACAO_DADO
# 0                         VIGENTE  04/23/2025 19:00:01
# 1                         VIGENTE  04/23/2025 19:00:01
# 2                      26/05/2035  04/23/2025 19:00:01
# 3                      26/05/2035  04/23/2025 19:00:01
# 4                      01/03/2034  04/23/2025 19:00:01
# ...                           ...                  ...
# 108001                    VIGENTE  04/23/2025 19:00:01
# 108002                    VIGENTE  04/23/2025 19:00:01
# 108003                    VIGENTE  04/23/2025 19:00:01
# 108004                    VIGENTE  04/23/2025 19:00:01
# 108005                    VIGENTE  04/23/2025 19:00:01
#
# [108006 rows x 12 columns]
